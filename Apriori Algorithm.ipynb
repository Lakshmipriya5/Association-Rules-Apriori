# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemset = apriori(df, min_support=0.6)
frequent_itemset
# Out:
#     support   itemsets
# 0       0.8        (3)
# 1       1.0        (5)
# 2       0.6        (6)
# 3       0.6        (8)
# 4       0.6       (10)
# 5       0.8     (3, 5)
# 6       0.6     (8, 3)
# 7       0.6     (5, 6)
# 8       0.6     (8, 5)
# 9       0.6    (10, 5)
# 10      0.6  (8, 3, 5)

# %%
frequent_itemset = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemset
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Kidney Beans, Eggs)
# 6       0.6                (Eggs, Onion)
# 7       0.6         (Kidney Beans, Milk)
# 8       0.6        (Kidney Beans, Onion)
# 9       0.6       (Kidney Beans, Yogurt)
# 10      0.6  (Kidney Beans, Eggs, Onion)

# %%
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#     support                     itemsets  length
# 0       0.8                       (Eggs)       1
# 1       1.0               (Kidney Beans)       1
# 2       0.6                       (Milk)       1
# 3       0.6                      (Onion)       1
# 4       0.6                     (Yogurt)       1
# 5       0.8         (Kidney Beans, Eggs)       2
# 6       0.6                (Eggs, Onion)       2
# 7       0.6         (Kidney Beans, Milk)       2
# 8       0.6        (Kidney Beans, Onion)       2
# 9       0.6       (Kidney Beans, Yogurt)       2
# 10      0.6  (Kidney Beans, Eggs, Onion)       3

# %%
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.8) ]
# Out:
#    support              itemsets  length
# 5      0.8  (Kidney Beans, Eggs)       2

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'Onion', 'Eggs'} ]
# Out:
#    support       itemsets  length
# 6      0.6  (Eggs, Onion)       2

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'Eggs', 'Onion'} ]
# Out:
#    support       itemsets  length
# 6      0.6  (Eggs, Onion)       2

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == frozenset(('Eggs', 'Onion')) ]
# Out:
#    support       itemsets  length
# 6      0.6  (Eggs, Onion)       2

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == frozenset(('Onion', 'Eggs')) ]
# Out:
#    support       itemsets  length
# 6      0.6  (Eggs, Onion)       2

# %%
oht_ary = te.fit(dataset).transform(dataset, sparse=True)
sparse_df = pd.SparseDataFrame(te_ary, columns=te.columns_, default_fill_value=False)
sparse_df
# Out:
# C:\Users\ELCOT\Documents\New folder\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: SparseDataFrame is deprecated and will be removed in a future version.
# Use a regular DataFrame whose columns are SparseArrays instead.
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#
# C:\Users\ELCOT\Documents\New folder\lib\site-packages\pandas\core\frame.py:3456: FutureWarning: SparseSeries is deprecated and will be removed in a future version.
# Use a Series with sparse values instead.
#
#     >>> series = pd.Series(pd.SparseArray(...))
#
# See http://pandas.pydata.org/pandas-docs/stable/user_guide/sparse.html#migrating for more.
#
#   return klass(values, index=self.index, name=items, fastpath=True)
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
apriori(sparse_df, min_support=0.6, use_colnames=True)
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Kidney Beans, Eggs)
# 6       0.6                (Eggs, Onion)
# 7       0.6         (Kidney Beans, Milk)
# 8       0.6        (Kidney Beans, Onion)
# 9       0.6       (Kidney Beans, Yogurt)
# 10      0.6  (Kidney Beans, Eggs, Onion)

# %%
from mlxtend.frequent_patterns import association_rules
frequent_itemsets = apriori(df, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#       antecedents     consequents  antecedent support  consequent support  \
# 0          (Eggs)         (Apple)                 0.8                 0.2
# 1         (Apple)          (Eggs)                 0.2                 0.8
# 2  (Kidney Beans)         (Apple)                 1.0                 0.2
# 3         (Apple)  (Kidney Beans)                 0.2                 1.0
# 4          (Milk)         (Apple)                 0.6                 0.2
#
#    support  confidence      lift  leverage  conviction
# 0      0.2    0.250000  1.250000      0.04    1.066667
# 1      0.2    1.000000  1.250000      0.04         inf
# 2      0.2    0.200000  1.000000      0.00    1.000000
# 3      0.2    1.000000  1.000000      0.00         inf
# 4      0.2    0.333333  1.666667      0.08    1.200000

# %%
rules[ (rules['lift'] >= 5) &
      (rules['confidence'] >= 0.6) ]
# Out:
#                             antecedents                         consequents  \
# 76                         (Eggs, Corn)                         (Ice cream)
# 77                          (Ice cream)                        (Eggs, Corn)
# 94                        (Onion, Corn)                         (Ice cream)
# 95                          (Ice cream)                       (Onion, Corn)
# 112                        (Milk, Corn)                           (Unicorn)
# 113                           (Unicorn)                        (Milk, Corn)
# 124                      (Yogurt, Corn)                           (Unicorn)
# 125                           (Unicorn)                      (Yogurt, Corn)
# 324          (Kidney Beans, Eggs, Corn)                         (Ice cream)
# 326           (Kidney Beans, Ice cream)                        (Eggs, Corn)
# 331                        (Eggs, Corn)           (Kidney Beans, Ice cream)
# 333                         (Ice cream)          (Kidney Beans, Eggs, Corn)
# 339                 (Eggs, Onion, Corn)                         (Ice cream)
# 340                   (Ice cream, Eggs)                       (Onion, Corn)
# 341                  (Ice cream, Onion)                        (Eggs, Corn)
# 344                        (Eggs, Corn)                  (Ice cream, Onion)
# 345                       (Onion, Corn)                   (Ice cream, Eggs)
# 346                         (Ice cream)                 (Eggs, Onion, Corn)
# 362         (Kidney Beans, Onion, Corn)                         (Ice cream)
# 364           (Kidney Beans, Ice cream)                       (Onion, Corn)
# 369                       (Onion, Corn)           (Kidney Beans, Ice cream)
# 371                         (Ice cream)         (Kidney Beans, Onion, Corn)
# 376          (Kidney Beans, Milk, Corn)                           (Unicorn)
# 378             (Kidney Beans, Unicorn)                        (Milk, Corn)
# 383                        (Milk, Corn)             (Kidney Beans, Unicorn)
# 385                           (Unicorn)          (Kidney Beans, Milk, Corn)
# 404        (Kidney Beans, Yogurt, Corn)                           (Unicorn)
# 406             (Kidney Beans, Unicorn)                      (Yogurt, Corn)
# 411                      (Yogurt, Corn)             (Kidney Beans, Unicorn)
# 413                           (Unicorn)        (Kidney Beans, Yogurt, Corn)
# 419                (Yogurt, Milk, Corn)                           (Unicorn)
# 420                   (Unicorn, Yogurt)                        (Milk, Corn)
# 421                     (Unicorn, Milk)                      (Yogurt, Corn)
# 424                      (Yogurt, Corn)                     (Unicorn, Milk)
# 425                        (Milk, Corn)                   (Unicorn, Yogurt)
# 426                           (Unicorn)                (Yogurt, Milk, Corn)
# 758   (Kidney Beans, Eggs, Onion, Corn)                         (Ice cream)
# 764         (Kidney Beans, Onion, Corn)                   (Ice cream, Eggs)
# 765    (Kidney Beans, Ice cream, Onion)                        (Eggs, Corn)
# 766          (Kidney Beans, Eggs, Corn)                  (Ice cream, Onion)
# 767     (Kidney Beans, Ice cream, Eggs)                       (Onion, Corn)
# 769                 (Eggs, Onion, Corn)           (Kidney Beans, Ice cream)
# 776           (Kidney Beans, Ice cream)                 (Eggs, Onion, Corn)
# 778                       (Onion, Corn)     (Kidney Beans, Ice cream, Eggs)
# 779                  (Ice cream, Onion)          (Kidney Beans, Eggs, Corn)
# 780                        (Eggs, Corn)    (Kidney Beans, Ice cream, Onion)
# 781                   (Ice cream, Eggs)         (Kidney Beans, Onion, Corn)
# 787                         (Ice cream)   (Kidney Beans, Eggs, Onion, Corn)
# 790  (Kidney Beans, Yogurt, Milk, Corn)                           (Unicorn)
# 794        (Kidney Beans, Yogurt, Corn)                     (Unicorn, Milk)
# 795          (Kidney Beans, Milk, Corn)                   (Unicorn, Yogurt)
# 796     (Kidney Beans, Unicorn, Yogurt)                        (Milk, Corn)
# 797       (Kidney Beans, Unicorn, Milk)                      (Yogurt, Corn)
# 801                (Yogurt, Milk, Corn)             (Kidney Beans, Unicorn)
# 804             (Kidney Beans, Unicorn)                (Yogurt, Milk, Corn)
# 808                      (Yogurt, Corn)       (Kidney Beans, Unicorn, Milk)
# 809                        (Milk, Corn)     (Kidney Beans, Unicorn, Yogurt)
# 810                   (Unicorn, Yogurt)          (Kidney Beans, Milk, Corn)
# 811                     (Unicorn, Milk)        (Kidney Beans, Yogurt, Corn)
# 815                           (Unicorn)  (Kidney Beans, Yogurt, Milk, Corn)
#
#      antecedent support  consequent support  support  confidence  lift  \
# 76                  0.2                 0.2      0.2         1.0   5.0
# 77                  0.2                 0.2      0.2         1.0   5.0
# 94                  0.2                 0.2      0.2         1.0   5.0
# 95                  0.2                 0.2      0.2         1.0   5.0
# 112                 0.2                 0.2      0.2         1.0   5.0
# 113                 0.2                 0.2      0.2         1.0   5.0
# 124                 0.2                 0.2      0.2         1.0   5.0
# 125                 0.2                 0.2      0.2         1.0   5.0
# 324                 0.2                 0.2      0.2         1.0   5.0
# 326                 0.2                 0.2      0.2         1.0   5.0
# 331                 0.2                 0.2      0.2         1.0   5.0
# 333                 0.2                 0.2      0.2         1.0   5.0
# 339                 0.2                 0.2      0.2         1.0   5.0
# 340                 0.2                 0.2      0.2         1.0   5.0
# 341                 0.2                 0.2      0.2         1.0   5.0
# 344                 0.2                 0.2      0.2         1.0   5.0
# 345                 0.2                 0.2      0.2         1.0   5.0
# 346                 0.2                 0.2      0.2         1.0   5.0
# 362                 0.2                 0.2      0.2         1.0   5.0
# 364                 0.2                 0.2      0.2         1.0   5.0
# 369                 0.2                 0.2      0.2         1.0   5.0
# 371                 0.2                 0.2      0.2         1.0   5.0
# 376                 0.2                 0.2      0.2         1.0   5.0
# 378                 0.2                 0.2      0.2         1.0   5.0
# 383                 0.2                 0.2      0.2         1.0   5.0
# 385                 0.2                 0.2      0.2         1.0   5.0
# 404                 0.2                 0.2      0.2         1.0   5.0
# 406                 0.2                 0.2      0.2         1.0   5.0
# 411                 0.2                 0.2      0.2         1.0   5.0
# 413                 0.2                 0.2      0.2         1.0   5.0
# 419                 0.2                 0.2      0.2         1.0   5.0
# 420                 0.2                 0.2      0.2         1.0   5.0
# 421                 0.2                 0.2      0.2         1.0   5.0
# 424                 0.2                 0.2      0.2         1.0   5.0
# 425                 0.2                 0.2      0.2         1.0   5.0
# 426                 0.2                 0.2      0.2         1.0   5.0
# 758                 0.2                 0.2      0.2         1.0   5.0
# 764                 0.2                 0.2      0.2         1.0   5.0
# 765                 0.2                 0.2      0.2         1.0   5.0
# 766                 0.2                 0.2      0.2         1.0   5.0
# 767                 0.2                 0.2      0.2         1.0   5.0
# 769                 0.2                 0.2      0.2         1.0   5.0
# 776                 0.2                 0.2      0.2         1.0   5.0
# 778                 0.2                 0.2      0.2         1.0   5.0
# 779                 0.2                 0.2      0.2         1.0   5.0
# 780                 0.2                 0.2      0.2         1.0   5.0
# 781                 0.2                 0.2      0.2         1.0   5.0
# 787                 0.2                 0.2      0.2         1.0   5.0
# 790                 0.2                 0.2      0.2         1.0   5.0
# 794                 0.2                 0.2      0.2         1.0   5.0
# 795                 0.2                 0.2      0.2         1.0   5.0
# 796                 0.2                 0.2      0.2         1.0   5.0
# 797                 0.2                 0.2      0.2         1.0   5.0
# 801                 0.2                 0.2      0.2         1.0   5.0
# 804                 0.2                 0.2      0.2         1.0   5.0
# 808                 0.2                 0.2      0.2         1.0   5.0
# 809                 0.2                 0.2      0.2         1.0   5.0
# 810                 0.2                 0.2      0.2         1.0   5.0
# 811                 0.2                 0.2      0.2         1.0   5.0
# 815                 0.2                 0.2      0.2         1.0   5.0
#
#      leverage  conviction
# 76       0.16         inf
# 77       0.16         inf
# 94       0.16         inf
# 95       0.16         inf
# 112      0.16         inf
# 113      0.16         inf
# 124      0.16         inf
# 125      0.16         inf
# 324      0.16         inf
# 326      0.16         inf
# 331      0.16         inf
# 333      0.16         inf
# 339      0.16         inf
# 340      0.16         inf
# 341      0.16         inf
# 344      0.16         inf
# 345      0.16         inf
# 346      0.16         inf
# 362      0.16         inf
# 364      0.16         inf
# 369      0.16         inf
# 371      0.16         inf
# 376      0.16         inf
# 378      0.16         inf
# 383      0.16         inf
# 385      0.16         inf
# 404      0.16         inf
# 406      0.16         inf
# 411      0.16         inf
# 413      0.16         inf
# 419      0.16         inf
# 420      0.16         inf
# 421      0.16         inf
# 424      0.16         inf
# 425      0.16         inf
# 426      0.16         inf
# 758      0.16         inf
# 764      0.16         inf
# 765      0.16         inf
# 766      0.16         inf
# 767      0.16         inf
# 769      0.16         inf
# 776      0.16         inf
# 778      0.16         inf
# 779      0.16         inf
# 780      0.16         inf
# 781      0.16         inf
# 787      0.16         inf
# 790      0.16         inf
# 794      0.16         inf
# 795      0.16         inf
# 796      0.16         inf
# 797      0.16         inf
# 801      0.16         inf
# 804      0.16         inf
# 808      0.16         inf
# 809      0.16         inf
# 810      0.16         inf
# 811      0.16         inf
# 815      0.16         inf
